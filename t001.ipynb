# %% [markdown]
# <a href="https://colab.research.google.com/github/phuekwonganan-del/tablet-compression-simulator/blob/main/t001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit -q

from rdkit import Chem
from rdkit.Chem import Draw, MACCSkeys, Descriptors, PandasTools, rdFingerprintGenerator
import pandas as pd
import matplotlib.pyplot as plt

print("✅ ทุกอย่างพร้อม!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 38.3 MB/s eta 0:00:00
# ✅ ทุกอย่างพร้อม!
